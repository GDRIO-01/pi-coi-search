# %%
import pandas as pd

# %%
applications = pd.read_csv('Applications_Ash.csv')

# %%
grants = pd.read_csv('Grants_Ash.csv')

# %%
#please input the GTL's name in the square brackets below e.g. 'Finn':
names_to_check = ['Finn']
pattern = '|'.join(names_to_check)
pi_coi_apps = applications[applications['PI Name'].str.contains(pattern) | applications['Participant List'].str.contains(pattern)]
pi_coi_grants = grants[grants['PI Name'].str.contains(pattern) | grants['List of participants (for short description)'].str.contains(pattern)]

# %%
apps_by_status = pi_coi_apps.groupby('Status')[['CONVERIS ID', 'Acronym', 'PI Name']]
grants_by_status = pi_coi_grants.groupby('Status')[['CONVERIS ID', 'Acronym', 'PI Name']]

# %%
for status, group in apps_by_status:
    print(f"Status: {status}")
    print(group.to_string(index=False))
    print("\n")
# Out:
# Status: Awarded
#  CONVERIS ID                       Acronym            PI Name
#         5212                   Plastizymes        Robert Finn
#         2395             ELIXIR-EXCELERATE    Niklas Blomberg
#         6506       HD_MA_COS-EMBL Workshop        Robert Finn
#         3937               AtlantECO-Resub       Guy Cochrane
#         4440             InterPro_Pfam_BRG       Alex Bateman
#         2548                   MG-RAST-EBI        Robert Finn
#         2223                      FuncFams        Robert Finn
#         3741                          Rfam       Alex Bateman
#         5280         sc4DMap - Jiawei Wang        Robert Finn
#         5553                       MICROBE    Anthony Burdett
#         3617                     OTAR2-048 Maria-Jesus Martin
#         3716           BBSRC Case Unilever        Robert Finn
#         5022            Holobiont Sciences        Robert Finn
#         2631                 InterPro-PDBe        Robert Finn
#         4683 EBI - 2020 - MicrobialBiotech        Robert Finn
#         3430                       EMERALD        Robert Finn
#         3318                     EOSC-Life    Niklas Blomberg
#         3740                 InterPro-Pfam        Robert Finn
#         5097          National MGN cluster        Robert Finn
#         3350                  EBI-2018-CWL        Robert Finn
#         2560                       MetXtra        Robert Finn
#         4033                       metaPUF        Robert Finn
#         2957           EBI-2017-Bioschemas    Helen Parkinson
#         5061               BlueRemediomics        Robert Finn
#         3882                         SENSE        Robert Finn
#         3883                 RNA resources        Robert Finn
#         4413                  FindingPheno        Robert Finn
#         2377                        UniFam        Robert Finn
#         3159                    MetaSPAdes        Robert Finn
#         2181                         MGPII        Robert Finn
#         4029                          OCIA        Robert Finn
#         3166                       MGP-III        Robert Finn
#         3511              Polymyxa Project        Robert Finn
#         3545                  EBI-2018-IDP        Robert Finn
#         6619                   Block Award   Johanna McEntyre
#         3566                      UniRules Maria-Jesus Martin
#         3541        EBI-2018-Clearinghouse       Guy Cochrane
#         2601                 RNAcentral II       Alex Bateman
#         2185                       RfamBBR       Alex Bateman
#         5217                     BIOcean5D        Edith Heard
#         5761                   DTO-BioFlow        Robert Finn
#         4823                        MGP-IV        Robert Finn
#         5599                BlueCloud 2026       Guy Cochrane
#         6002                       EUREMAP        Robert Finn
#         6297                        MIMICC        Robert Finn
#         6183                IMDM-microfund        Robert Finn
#         3549            EBI-2018-Structure    Sameer Velankar
#         4874                       PDBe-KB    Sameer Velankar
#         3443                       REFRACT        Robert Finn
#         3415                      HoloFood        Robert Finn
#         4829                      REDEFINE        Robert Finn
#         5842         2022-FoodandNutrition        Robert Finn
#         4192                  COFUND_ARISE          Peer Bork
#         6054                     INFECTOME        Robert Finn
#         6065                         AEGIS      Fergal Martin
#
#
# Status: In Negotiation
#  CONVERIS ID    Acronym     PI Name
#         6594 E!-FungiDB Robert Finn
#
#
# Status: In Progress
#  CONVERIS ID       Acronym     PI Name
#         6992 IntegroHEALTH Robert Finn
#         6582     TBC: MEPB Robert Finn
#         6519  TBC: eMGnify Robert Finn
#
#
# Status: In preparation
#  CONVERIS ID      Acronym     PI Name
#         6802 TBC: EMBRACE Robert Finn
#
#
# Status: Submitted to funding body
#  CONVERIS ID                  Acronym     PI Name
#         6930         MetaExplore-2024 Robert Finn
#         6532             INFRA-STRAIN Robert Finn
#         6966 SPP2474-Z02-Gut-Microbes Robert Finn
#         6877                   EMeRGE Robert Finn
#         6878              TBC: PANFER Robert Finn
#
#
# Status: Unsuccessful
#  CONVERIS ID                            Acronym                        PI Name
#         2098                            SUSTAIN                   Guy Cochrane
#         6298                           SUPANOVA                    Robert Finn
#         5542                   Rhizo-resilience                    Robert Finn
#         4995                 eAMR and human gut                    Robert Finn
#         2573                         IMAGEOMICS                    Robert Finn
#         3014                          ITN-ROMAN                    Robert Finn
#         3604                               DIPD                    Robert Finn
#         4030                         Global Gut                    Robert Finn
#         4256                          SeaSCAPES                    Robert Finn
#         5373                        MetaDropEvo                    Robert Finn
#         3558                           FunGraft                    Robert Finn
#         5430                             AQUire                Plamena Markova
#         5260                            FunPath                     Sarah Dyer
#         4815       Oral Metagenome - Gingivitis                    Robert Finn
#         3265                      MarMetESASTAP                    Robert Finn
#         3467                          Metagen4A                    Robert Finn
#         3495                            MINERVA                    Robert Finn
#         4016                             OGM-CC                    Robert Finn
#         3165                           Rfam2017                   Alex Bateman
#         4547 Gut microbiota-diarrhoeal patients                    Robert Finn
#         5632                          EPSRC-IME                    Robert Finn
#         4768                       MicroBiomeUK                    Robert Finn
#         5624              WGC biodiversity - PE                    Robert Finn
#         5625                   Mitometagenomics                    Robert Finn
#         4416                           EMMBRACE                    Robert Finn
#         2569                         HMMER-ETOP                    Robert Finn
#         4064                               SitS                    Robert Finn
#         5438                               IRIS            Evangelia Petsalaki
#         5295                      GreenDroplets                    Robert Finn
#         4427                         Gingivitis                    Robert Finn
#         2176                          CDIFF2020                    Robert Finn
#         2182                             MEROPS                    Robert Finn
#         2482                       METANBIOTICS                    Robert Finn
#         4215                            EMRI-DS                    Robert Finn
#         2224                             HMMERx                    Robert Finn
#         2561                             HMMERx                    Robert Finn
#         3158                              CAPER                    Robert Finn
#         2106                          BlueZymes                    Robert Finn
#         3875                  EBI-2019-SeqDiver                    Robert Finn
#         3397                         ROMAN-2018                    Robert Finn
#         3240                               FAST                    Robert Finn
#         3407                           PolyGEMS                    Robert Finn
#         3399                             ENSURE                    Robert Finn
#         3040                               Ai3o                    Robert Finn
#         2846           EMG-nasopharyngeal-biome                    Robert Finn
#         2137                           MetaMine                    Robert Finn
#         2954                   InterPro-Pfam-GP                    Robert Finn
#         2190                               GSMN                   Guy Cochrane
#         2055                            METAGAP                   Guy Cochrane
#         3345                           Gut4Mood                   Guy Cochrane
#         2480                        MetaBioTECH                   Guy Cochrane
#         3903                               FuRI                    Robert Finn
#         5380                        MetaExplore                    Robert Finn
#         5327                        Deep Virome                    Robert Finn
#         4985                         PathoBiome                    Robert Finn
#         6089               INTEGROHEALTH_Latvia                Plamena Markova
#         3629                             MAGPIE Juan Antonio Vizcaino Gonzalez
#         6396         MetaExplore (resubmission)                    Robert Finn
#         5797                         MGnifyRAST                    Robert Finn
#         6008                    CoRE Microbiome                    Robert Finn
#         6311                          COMBIPHYT                     Sarah Dyer
#         5554                       PathoBiome 2                    Robert Finn
#
#
# Status: Withdrawn
#  CONVERIS ID                                  Acronym      PI Name
#         3433                                      TBD Andrew Leach
#         3581                                    UMBRA  Robert Finn
#         3583                                     Rfam  Robert Finn
#         3340                                 SynthBio  Robert Finn
#         4384                                   FuRI-2  Robert Finn
#         5118      TBC: Phytoplankton trait plasticity  Robert Finn
#         5127 Innovators in Science - Gastroenterology  Robert Finn
#         2620                   Imageomics - Eurostars  Robert Finn
#         5051                              AMR in HuGM  Robert Finn
#         3447                     Human gut microbiome  Robert Finn
#         3264                          CRUK-Microbiome  Robert Finn
#         3881                                    UMBRA  Robert Finn
#         6293                          TBC: eDNA-Sense  Robert Finn

# %%
for status, group in grants_by_status:
    print(f"Status: {status}")
    print(group.to_string(index=False))
    print("\n")
# Out:
# Status: Closed
#  CONVERIS ID                       Acronym            PI Name
#         3350                  EBI-2018-CWL        Robert Finn
#         3617                     OTAR2-048 Maria-Jesus Martin
#         2957           EBI-2017-Bioschemas    Helen Parkinson
#         4683 EBI - 2020 - MicrobialBiotech        Robert Finn
#         4029                          OCIA        Robert Finn
#         6506       HD_MA_COS-EMBL Workshop        Robert Finn
#         2601                 RNAcentral II       Alex Bateman
#         1865            InterPro_Pfam_2013        Robert Finn
#         3159                    MetaSPAdes        Robert Finn
#         2181                         MGPII        Robert Finn
#         6183                IMDM-microfund        Robert Finn
#         3566                      UniRules Maria-Jesus Martin
#         1509                      Micro B3       Guy Cochrane
#         3541        EBI-2018-Clearinghouse       Guy Cochrane
#         3549            EBI-2018-Structure    Sameer Velankar
#         3545                  EBI-2018-IDP        Robert Finn
#         3716           BBSRC Case Unilever        Robert Finn
#         2548                   MG-RAST-EBI        Robert Finn
#         3511              Polymyxa Project        Robert Finn
#         5280         sc4DMap - Jiawei Wang        Robert Finn
#         5842         2022-FoodandNutrition        Robert Finn
#         3741                          Rfam       Alex Bateman
#         2560                       MetXtra        Robert Finn
#         2223                      FuncFams        Robert Finn
#         3430                       EMERALD        Robert Finn
#         1488                      Mgportal       Guy Cochrane
#         3882                         SENSE        Robert Finn
#         3166                       MGP-III        Robert Finn
#         3415                      HoloFood        Robert Finn
#         2377                        UniFam        Robert Finn
#         2395             ELIXIR-EXCELERATE    Niklas Blomberg
#         3318                     EOSC-Life    Niklas Blomberg
#         3443                       REFRACT        Robert Finn
#         4033                       metaPUF        Robert Finn
#         2631                 InterPro-PDBe        Robert Finn
#         1544                        IDA2GO       Sarah Hunter
#         4373                       SymbNET   Athanasios Typas
#         2988                   HGNC III WT        Ewan Birney
#         3125                  HGNC III U24        Ewan Birney
#         2185                       RfamBBR       Alex Bateman
#
#
# Status: In Progress
#  CONVERIS ID     Acronym          PI Name
#         6297      MIMICC      Robert Finn
#         6619 Block Award Johanna McEntyre
#
#
# Status: Live
#  CONVERIS ID              Acronym         PI Name
#         4829             REDEFINE     Robert Finn
#         5553              MICROBE Anthony Burdett
#         3686            Ensembl V     Robert Finn
#         5061      BlueRemediomics     Robert Finn
#         4192         COFUND_ARISE       Peer Bork
#         4874              PDBe-KB Sameer Velankar
#         6002              EUREMAP     Robert Finn
#         5217            BIOcean5D     Edith Heard
#         6054            INFECTOME     Robert Finn
#         5022   Holobiont Sciences     Robert Finn
#         5212          Plastizymes     Robert Finn
#         5761          DTO-BioFlow     Robert Finn
#         4413         FindingPheno     Robert Finn
#         4823               MGP-IV     Robert Finn
#         5599       BlueCloud 2026    Guy Cochrane
#         6065                AEGIS   Fergal Martin
#         5097 National MGN cluster     Robert Finn
#         4440  InterPro-Pfam-HMMER    Alex Bateman
#         3937      AtlantECO-Resub    Guy Cochrane

# %%
#print(pi_coi_apps[['CONVERIS ID', 'Acronym', 'PI Name']].to_string(index=False))

# %%
#print(pi_coi_grants[['CONVERIS ID', 'Acronym', 'PI Name']].to_string(index=False))
